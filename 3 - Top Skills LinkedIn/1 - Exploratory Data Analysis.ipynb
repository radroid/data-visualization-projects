# %% [markdown]
# # Exploratory Data Analysis
#
# ## Assignment Objective
# Data stories help stakeholders clearly understand the data and create a sense of urgency to make decisions based on that data. Your objective is to create a data story to recommend to different stakeholder groups the top five data skills needed in a data science training program.
#
# ## Scenario
# Your director has decided to invest in a data science training program. **To help with design and vendor selection your director wants you to determine the top five skills that many feel companies need**. As part of the decision making process, you need to present your findings as a data story to **business experts, management, and technical staff.**
#
#
# ## Key information
# > **Audience**: Business Experts, management and technical staff.
# <br>
# > **Goal**: To help with design and vendor selection, determine the top five skills in a data science training program.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('Data Set.xlsx')
df
# Out:
#                                           Skill        Country  Year  Rank
# 0                              Algorithm Design      Australia  2015    13
# 1                              Algorithm Design      Australia  2016     9
# 2                         Business Intelligence      Australia  2014     6
# 3                         Business Intelligence      Australia  2015    21
# 4                                         C/C++      Australia  2014    17
# ..                                          ...            ...   ...   ...
# 793                              Virtualization  United States  2014    22
# 794                              Virtualization  United States  2015    17
# 795  Web Architecture and Development Framework  United States  2014    17
# 796  Web Architecture and Development Framework  United States  2015    10
# 797  Web Architecture and Development Framework  United States  2016     8
#
# [798 rows x 4 columns]

# %%
df.Country.value_counts()
# Out:
# Australia               60
# Canada                  60
# France                  60
# Global                  60
# India                   60
# Netherlands             60
# South Africa            60
# United Arab Emirates    60
# United Kingdom          60
# United States           60
# Brazil                  58
# China                   35
# Germany                 35
# Ireland                 35
# Singapore               35
# Name: Country, dtype: int64

# %%
df.Skill.value_counts()
# Out:
# Statistical Analysis and Data Mining          41
# Web Architecture and Development Framework    35
# Mobile Development                            34
# Network and Information Security              34
# Middleware and Integration Software           32
#                                               ..
# Financial Analysis and Modeling                1
# Dispute Resolution Law                         1
# TV and Video Production                        1
# Microsoft Windows Systems                      1
# Renewable and Sustainable Energy               1
# Name: Skill, Length: 70, dtype: int64

# %%
df.describe().round()
# Out:
#          Year   Rank
# count   798.0  798.0
# mean   2015.0   12.0
# std       1.0    7.0
# min    2014.0    1.0
# 25%    2014.0    5.0
# 50%    2015.0   10.0
# 75%    2015.0   18.0
# max    2016.0   25.0

# %%
df2 = pd.read_excel('LinkedInTopSkills.xlsx')
df2
# Out:
# /Users/raj/Documents/DurhamCollege/AI/Semester_1/Capstone-AIDI-1003/spoiler-buster/env/lib/python3.9/site-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
#     Year Published  Top Skills Year  Rank  \
# 0             2018             2017     1
# 1             2018             2017     2
# 2             2018             2017     3
# 3             2018             2017     4
# 4             2018             2017     5
# 5             2018             2017     6
# 6             2018             2017     7
# 7             2018             2017     8
# 8             2018             2017     9
# 9             2018             2017    10
# 10            2017             2016     1
# 11            2017             2016     2
# 12            2017             2016     3
# 13            2017             2016     4
# 14            2017             2016     5
# 15            2017             2016     6
# 16            2017             2016     7
# 17            2017             2016     8
# 18            2017             2016     9
# 19            2017             2016    10
# 20            2016             2015     1
# 21            2016             2015     2
# 22            2016             2015     3
# 23            2016             2015     4
# 24            2016             2015     5
# 25            2016             2015     6
# 26            2016             2015     7
# 27            2016             2015     8
# 28            2016             2015     9
# 29            2016             2015    10
# 30            2015             2014     1
# 31            2015             2014     2
# 32            2015             2014     3
# 33            2015             2014     4
# 34            2015             2014     5
# 35            2015             2014     6
# 36            2015             2014     7
# 37            2015             2014     8
# 38            2015             2014     9
# 39            2015             2014    10
# 40            2014             2013     1
# 41            2014             2013     2
# 42            2014             2013     3
# 43            2014             2013     4
# 44            2014             2013     5
# 45            2014             2013     6
# 46            2014             2013     7
# 47            2014             2013     8
# 48            2014             2013     9
# 49            2014             2013    10
#
#                                            Skill  Region  \
# 0                Cloud and Distributed Computing      US
# 1           Statistical Analysis and Data Mining      US
# 2            Middleware and Integration Software      US
# 3     Web Architecture and Development Framework      US
# 4                          User Interface Design      US
# 5              Software Revision Control Systems      US
# 6                              Data Presentation      US
# 7                              SEO/SEM Marketing      US
# 8                             Mobile Development      US
# 9               Network and Information Security      US
# 10               Cloud and Distributed Computing  Global
# 11          Statistical Analysis and Data Mining  Global
# 12    Web Architecture and Development Framework  Global
# 13           Middleware and Integration Software  Global
# 14                         User Interface Design  Global
# 15              Network and Information Security  Global
# 16                            Mobile Development  Global
# 17                             Data Presentation  Global
# 18                             SEO/SEM Marketing  Global
# 19                Storage Systems and Management  Global
# 20               Cloud and Distributed Computing  Global
# 21          Statistical Analysis and Data Mining  Global
# 22                 Marketing Campaign Management  Global
# 23                             SEO/SEM Marketing  Global
# 24           Middleware and Integration Software  Global
# 25                            Mobile Development  Global
# 26              Network and Information Security  Global
# 27                Storage Systems and Management  Global
# 28    Web Architecture and Development Framework  Global
# 29                         User Interface Design  Global
# 30          Statistical Analysis and Data Mining  Global
# 31           Middleware and Integration Software  Global
# 32                Storage Systems and Management  Global
# 33              Network and Information Security  Global
# 34                             SEO/SEM Marketing  Global
# 35                         Business Intelligence  Global
# 36                            Mobile Development  Global
# 37    Web Architecture and Development Framework  Global
# 38                              Algorithm Design  Global
# 39                              Perl/Python/Ruby  Global
# 40                        Social Media Marketing     NaN
# 41                            Mobile Development     NaN
# 42               Cloud and Distributed Computing     NaN
# 43                              Perl/Python/Ruby     NaN
# 44          Statistical Analysis and Data Mining     NaN
# 45                         User Interface Design     NaN
# 46                  Digital and Online Marketing     NaN
# 47                                    Recruiting     NaN
# 48  Business Development/Relationship Management     NaN
# 49        Retail Payment and Information Systems     NaN
#
#    Comparable to previous year?  \
# 0                           Yes
# 1                           Yes
# 2                           Yes
# 3                           Yes
# 4                           Yes
# 5                           Yes
# 6                           Yes
# 7                           Yes
# 8                           Yes
# 9                           Yes
# 10                          Yes
# 11                          Yes
# 12                          Yes
# 13                          Yes
# 14                          Yes
# 15                          Yes
# 16                          Yes
# 17                          Yes
# 18                          Yes
# 19                          Yes
# 20                          Yes
# 21                          Yes
# 22                          Yes
# 23                          Yes
# 24                          Yes
# 25                          Yes
# 26                          Yes
# 27                          Yes
# 28                          Yes
# 29                          Yes
# 30                           No
# 31                           No
# 32                           No
# 33                           No
# 34                           No
# 35                           No
# 36                           No
# 37                           No
# 38                           No
# 39                           No
# 40                          NaN
# 41                          NaN
# 42                          NaN
# 43                          NaN
# 44                          NaN
# 45                          NaN
# 46                          NaN
# 47                          NaN
# 48                          NaN
# 49                          NaN
#
#                                                   URL
# 0   https://blog.linkedin.com/2018/january/11/link...
# 1   https://blog.linkedin.com/2018/january/11/link...
# 2   https://blog.linkedin.com/2018/january/11/link...
# 3   https://blog.linkedin.com/2018/january/11/link...
# 4   https://blog.linkedin.com/2018/january/11/link...
# 5   https://blog.linkedin.com/2018/january/11/link...
# 6   https://blog.linkedin.com/2018/january/11/link...
# 7   https://blog.linkedin.com/2018/january/11/link...
# 8   https://blog.linkedin.com/2018/january/11/link...
# 9   https://blog.linkedin.com/2018/january/11/link...
# 10  https://blog.linkedin.com/2016/10/20/top-skill...
# 11  https://blog.linkedin.com/2016/10/20/top-skill...
# 12  https://blog.linkedin.com/2016/10/20/top-skill...
# 13  https://blog.linkedin.com/2016/10/20/top-skill...
# 14  https://blog.linkedin.com/2016/10/20/top-skill...
# 15  https://blog.linkedin.com/2016/10/20/top-skill...
# 16  https://blog.linkedin.com/2016/10/20/top-skill...
# 17  https://blog.linkedin.com/2016/10/20/top-skill...
# 18  https://blog.linkedin.com/2016/10/20/top-skill...
# 19  https://blog.linkedin.com/2016/10/20/top-skill...
# 20  https://blog.linkedin.com/2016/01/12/the-25-sk...
# 21  https://blog.linkedin.com/2016/01/12/the-25-sk...
# 22  https://blog.linkedin.com/2016/01/12/the-25-sk...
# 23  https://blog.linkedin.com/2016/01/12/the-25-sk...
# 24  https://blog.linkedin.com/2016/01/12/the-25-sk...
# 25  https://blog.linkedin.com/2016/01/12/the-25-sk...
# 26  https://blog.linkedin.com/2016/01/12/the-25-sk...
# 27  https://blog.linkedin.com/2016/01/12/the-25-sk...
# 28  https://blog.linkedin.com/2016/01/12/the-25-sk...
# 29  https://blog.linkedin.com/2016/01/12/the-25-sk...
# 30  https://blog.linkedin.com/2014/12/17/the-25-ho...
# 31  https://blog.linkedin.com/2014/12/17/the-25-ho...
# 32  https://blog.linkedin.com/2014/12/17/the-25-ho...
# 33  https://blog.linkedin.com/2014/12/17/the-25-ho...
# 34  https://blog.linkedin.com/2014/12/17/the-25-ho...
# 35  https://blog.linkedin.com/2014/12/17/the-25-ho...
# 36  https://blog.linkedin.com/2014/12/17/the-25-ho...
# 37  https://blog.linkedin.com/2014/12/17/the-25-ho...
# 38  https://blog.linkedin.com/2014/12/17/the-25-ho...
# 39  https://blog.linkedin.com/2014/12/17/the-25-ho...
# 40  https://blog.linkedin.com/2013/12/18/the-25-ho...
# 41  https://blog.linkedin.com/2013/12/18/the-25-ho...
# 42  https://blog.linkedin.com/2013/12/18/the-25-ho...
# 43  https://blog.linkedin.com/2013/12/18/the-25-ho...
# 44  https://blog.linkedin.com/2013/12/18/the-25-ho...
# 45  https://blog.linkedin.com/2013/12/18/the-25-ho...
# 46  https://blog.linkedin.com/2013/12/18/the-25-ho...
# 47  https://blog.linkedin.com/2013/12/18/the-25-ho...
# 48  https://blog.linkedin.com/2013/12/18/the-25-ho...
# 49  https://blog.linkedin.com/2013/12/18/the-25-ho...

# %%
df2.describe()
# Out:
#        Year Published  Top Skills Year       Rank
# count       50.000000        50.000000  50.000000
# mean      2016.000000      2015.000000   5.500000
# std          1.428571         1.428571   2.901442
# min       2014.000000      2013.000000   1.000000
# 25%       2015.000000      2014.000000   3.000000
# 50%       2016.000000      2015.000000   5.500000
# 75%       2017.000000      2016.000000   8.000000
# max       2018.000000      2017.000000  10.000000

# %%
df2.Region.value_counts()
# Out:
# Global    30
# US        10
# Name: Region, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 798 entries, 0 to 797
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Skill    798 non-null    object
#  1   Country  798 non-null    object
#  2   Year     798 non-null    int64
#  3   Rank     798 non-null    int64
# dtypes: int64(2), object(2)
# memory usage: 25.1+ KB

# %%
list(df['Skill'].unique())
# Out:
# ['Algorithm Design',
#  'Business Intelligence',
#  'C/C++',
#  'Channel Marketing',
#  'Clinical Research and Trials',
#  'Computer Graphics and Animation',
#  'Corporate Law and Governance',
#  'Data Engineering and Data Warehousing',
#  'Database Management and Software',
#  'Economics',
#  'Electronic and Electrical Engineering',
#  'Foreign Language Translation',
#  'HR Benefits and Compensation',
#  'Java Development',
#  'Mac, Linux and Unix Systems',
#  'Marketing Campaign Management',
#  'Middleware and Integration Software',
#  'Mobile Development',
#  'Network and Information Security',
#  'Non-Profit, Fundraising, and Grantmaking',
#  'Perl/Python/Ruby',
#  'Public Policy and International Relations',
#  'Recruiting',
#  'SAP ERP Systems',
#  'SEO/SEM Marketing',
#  'Shell Scripting Languages',
#  'Social Media Marketing',
#  'Software QA and User Testing',
#  'Statistical Analysis and Data Mining',
#  'Storage Systems and Management',
#  'User Interface Design',
#  'Web Architecture and Development Framework',
#  'Automotive Services, Parts and Design',
#  'Business Development and Relationship Management',
#  'Digital and Online Marketing',
#  'IBM Mainframes and Systems',
#  'Integrated Circuit (IC) Design',
#  'Materials Engineering',
#  'Microsoft Application Development',
#  'Microsoft Windows Systems',
#  'Software Modeling and Process Design',
#  'Software Revision Control Systems',
#  'Workplace Safety',
#  'Data Presentation',
#  'Brand Strategy and Management',
#  'Cloud and Distributed Computing',
#  'PR and Communications',
#  'Retail Store Operations',
#  'TV and Video Production',
#  'Virtualization',
#  'Writing and Publishing',
#  'Compliance and Employment Law',
#  'Dispute Resolution Law',
#  'Financial Analysis and Modeling',
#  'Mathematics',
#  'Mechanical and Aerospace Engineering',
#  'Restaurants and Catering',
#  'Game Development',
#  'Market Research and Insights',
#  'Military and Defense',
#  'Administrative and Office Management',
#  'Litigation',
#  'Mining and Commodities',
#  'Radio Broadcasting',
#  'Oil and Gas, Subsea Engineering/Offshore Operations',
#  'Database and Direct Marketing',
#  'Financial Planning',
#  'Home Improvement',
#  'Real Estate Rental',
#  'Renewable and Sustainable Energy']

# %%
imp_it_skills = [
    'Algorithm Design',
    'Business Intelligence',
    'Computer Graphics and Animation',
    'Data Engineering and Data Warehousing',
    'Database Management and Software',
    'Java Development',
    'Mac, Linux and Unix Systems',
    'Middleware and Integration Software',
    'Mobile Development',
    'Network and Information Security',
    'Perl/Python/Ruby',
    'SAP ERP Systems',
    'SEO/SEM Marketing',
    'Shell Scripting Languages',
    'Software QA and User Testing',
    'Statistical Analysis and Data Mining',
    'Storage Systems and Management',
    'User Interface Design',
    'Web Architecture and Development Framework',
    'Digital and Online Marketing',
    'IBM Mainframes and Systems',
    'Integrated Circuit (IC) Design',
    'Microsoft Application Development',
    'Microsoft Windows Systems',
    'Software Modeling and Process Design',
    'Software Revision Control Systems',
    'Data Presentation',
    'Cloud and Distributed Computing',
    'Virtualization',
    'Financial Analysis and Modeling',
    'Mathematics',
    'Game Development',
    'Database and Direct Marketing'
]

# %%
imp_ds_skills = [
    'Business Intelligence',
    'Data Engineering and Data Warehousing',
    'Database Management and Software',
    'Perl/Python/Ruby',
    'Statistical Analysis and Data Mining',
    'Microsoft Application Development',
    'Software Modeling and Process Design',
    'Data Presentation',
    'Cloud and Distributed Computing',
    'Financial Analysis and Modeling',
    'Mathematics',
    'Database and Direct Marketing'
]

# %%
ds_df = df[df['Skill'].isin(imp_ds_skills)]
ds_df
# Out:
#                                      Skill        Country  Year  Rank
# 2                    Business Intelligence      Australia  2014     6
# 3                    Business Intelligence      Australia  2015    21
# 10   Data Engineering and Data Warehousing      Australia  2014    15
# 11   Data Engineering and Data Warehousing      Australia  2015    17
# 12        Database Management and Software      Australia  2014    24
# ..                                     ...            ...   ...   ...
# 776                       Perl/Python/Ruby  United States  2014    10
# 777                       Perl/Python/Ruby  United States  2015    13
# 784   Statistical Analysis and Data Mining  United States  2014     2
# 785   Statistical Analysis and Data Mining  United States  2015     2
# 786   Statistical Analysis and Data Mining  United States  2016     2
#
# [186 rows x 4 columns]

# %%
ds_df.Country.value_counts()
# Out:
# Netherlands             18
# France                  16
# United Kingdom          16
# Global                  14
# South Africa            14
# Brazil                  13
# Canada                  13
# India                   13
# United States           13
# Germany                 12
# Ireland                 11
# Australia               10
# China                    9
# United Arab Emirates     8
# Singapore                6
# Name: Country, dtype: int64

# %%
it_df = df[df['Skill'].isin(imp_it_skills)]
it_df
# Out:
#                                           Skill        Country  Year  Rank
# 0                              Algorithm Design      Australia  2015    13
# 1                              Algorithm Design      Australia  2016     9
# 2                         Business Intelligence      Australia  2014     6
# 3                         Business Intelligence      Australia  2015    21
# 7               Computer Graphics and Animation      Australia  2014    13
# ..                                          ...            ...   ...   ...
# 793                              Virtualization  United States  2014    22
# 794                              Virtualization  United States  2015    17
# 795  Web Architecture and Development Framework  United States  2014    17
# 796  Web Architecture and Development Framework  United States  2015    10
# 797  Web Architecture and Development Framework  United States  2016     8
#
# [579 rows x 4 columns]

# %%
it_df.Country.value_counts()
# Out:
# Global                  51
# United States           51
# Canada                  49
# Netherlands             46
# United Kingdom          46
# Brazil                  44
# India                   43
# Australia               42
# South Africa            42
# United Arab Emirates    37
# France                  36
# Ireland                 29
# Germany                 23
# China                   22
# Singapore               18
# Name: Country, dtype: int64

# %%
v_df = df[df['Skill'] == 'Virtualization']
v_df
# Out:
#               Skill        Country  Year  Rank
# 209  Virtualization          China  2015     4
# 210  Virtualization          China  2016     1
# 363  Virtualization         Global  2014    25
# 364  Virtualization         Global  2015    17
# 423  Virtualization          India  2014    15
# 424  Virtualization          India  2015    10
# 793  Virtualization  United States  2014    22
# 794  Virtualization  United States  2015    17

# %%
fig, ax = plt.subplots()

ax.plot('Year', 'Rank', data=v_df)

# %%
display(df)
# Out:
#                                           Skill        Country  Year  Rank
# 0                              Algorithm Design      Australia  2015    13
# 1                              Algorithm Design      Australia  2016     9
# 2                         Business Intelligence      Australia  2014     6
# 3                         Business Intelligence      Australia  2015    21
# 4                                         C/C++      Australia  2014    17
# ..                                          ...            ...   ...   ...
# 793                              Virtualization  United States  2014    22
# 794                              Virtualization  United States  2015    17
# 795  Web Architecture and Development Framework  United States  2014    17
# 796  Web Architecture and Development Framework  United States  2015    10
# 797  Web Architecture and Development Framework  United States  2016     8
#
# [798 rows x 4 columns]

# %%
v_df2 = v_df.pivot(index='Year', columns='Country', values='Rank')
v_df2
# Out:
# Country  China  Global  India  United States
# Year
# 2014       NaN    25.0   15.0           22.0
# 2015       4.0    17.0   10.0           17.0
# 2016       1.0     NaN    NaN            NaN

# %%
v_df2.plot()
# Out:
# <AxesSubplot:xlabel='Year'>
